# %%
from Bert_like import Bert_like
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
from torch.nn.utils.rnn import pad_sequence

myModel = Bert_like()
x = torch.arange(0, 100*100*55, dtype=torch.float).reshape(100, 100, 55)
print(x.shape)

x = myModel(x)
print(x.shape)
print(x)
# Out:
# torch.Size([512]) torch.Size([16])
# torch.Size([100, 100, 55])
# torch.Size([100, 100, 32])
# tensor([[[ 1.4478,  1.0984,  1.8316,  ...,  2.5029,  0.0858, -1.2054],
#          [ 0.4162,  2.3150,  2.1505,  ...,  1.8134,  0.4539, -0.9200],
#          [ 0.7523,  1.4341,  2.3537,  ...,  1.7054,  0.7870, -0.9370],
#          ...,
#          [ 1.0010,  0.3433,  1.4905,  ...,  2.0510,  1.2107, -0.8089],
#          [ 0.8986,  0.7135,  1.6181,  ...,  2.0564,  1.3640, -0.7022],
#          [ 0.5858,  0.8520,  1.4412,  ...,  1.5006,  1.4638, -0.6501]],
#
#         [[ 0.8469,  1.3434,  1.6345,  ...,  1.5460,  1.4499, -0.8007],
#          [ 0.5221,  1.6804,  1.8285,  ...,  2.1338,  1.1800, -0.8607],
#          [ 0.6992,  2.0279,  1.5097,  ...,  1.6614,  0.7758, -0.6878],
#          ...,
#          [ 1.0780,  1.3931,  2.2749,  ...,  2.0875,  1.0420, -1.3169],
#          [ 0.7058,  0.6851,  1.9961,  ...,  2.2651,  1.3138, -0.7837],
#          [ 0.7322,  0.9539,  1.8254,  ...,  2.2216,  1.2864, -0.7004]],
#
#         [[ 0.3149,  1.2721,  2.3142,  ...,  2.1808,  0.9574, -1.1358],
#          [ 0.7543,  1.4710,  1.8957,  ...,  1.7524,  1.5202, -0.6385],
#          [ 0.9866,  1.6984,  2.0558,  ...,  1.8641,  1.0545, -0.7586],
#          ...,
#          [ 0.7239,  1.1235,  2.2268,  ...,  2.4067,  1.3649, -0.8997],
#          [ 0.7774,  0.9640,  2.0950,  ...,  2.2964,  1.2004, -0.8351],
#          [ 0.6107,  1.0733,  2.5425,  ...,  2.3817,  0.5038, -1.0773]],
#
#         ...,
#
#         [[ 0.6411,  1.2502,  2.4367,  ...,  2.2624,  0.6769, -0.6361],
#          [ 0.8279,  1.5117,  2.2975,  ...,  1.2784,  1.0425, -0.6937],
#          [ 0.6842,  1.7589,  1.9293,  ...,  0.8376,  1.3229, -0.3958],
#          ...,
#          [ 0.8154,  1.0909,  2.4582,  ...,  2.2736,  1.3107, -1.2426],
#          [ 0.9417,  1.4952,  2.6834,  ...,  1.6385,  0.9144, -1.3660],
#          [ 0.6515,  1.1441,  2.5002,  ...,  2.3285,  0.8479, -0.9751]],
#
#         [[ 0.4218,  1.2897,  1.9454,  ...,  1.6218,  1.5523, -0.9040],
#          [ 0.6196,  1.0437,  2.0711,  ...,  2.0282,  1.0885, -0.8432],
#          [ 0.5935,  1.3321,  1.7996,  ...,  2.1093,  1.4748, -0.1355],
#          ...,
#          [ 0.8079,  1.0874,  2.6660,  ...,  2.1242,  1.4305, -0.9590],
#          [ 0.5967,  1.0496,  2.5274,  ...,  2.5654,  0.7134, -0.9663],
#          [ 0.6971,  1.3465,  2.4659,  ...,  2.4558,  0.6127, -0.9854]],
#
#         [[ 0.9535,  0.8941,  2.2092,  ...,  1.8960,  1.1813, -0.4234],
#          [ 0.7521,  1.0560,  2.0861,  ...,  1.9959,  0.9012, -0.5974],
#          [ 0.5909,  1.5486,  1.7735,  ...,  1.6795,  0.6463, -0.6547],
#          ...,
#          [ 0.6401,  1.2859,  2.4421,  ...,  1.4534,  1.3446, -0.7946],
#          [ 0.7571,  0.8722,  2.0739,  ...,  1.6950,  1.4866, -1.0753],
#          [ 0.8221,  1.1408,  2.3625,  ...,  2.0765,  1.2488, -0.6721]]],
#        grad_fn=<NativeLayerNormBackward0>)
